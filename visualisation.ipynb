# %%
import pandas as pd
import numpy as np
from shapely import wkt
import geopandas
import statistics
from scipy import stats

# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./8.csv",names=['Coordinates'])
df
# Out:
#                                              Coordinates
# 0      POLYGON ((59337.8372 2722924.84048778,59337.83...
# 1      POLYGON ((1051937.8372 2725024.84048778,105153...
# 2      POLYGON ((351037.8372 2718624.84048778,351037....
# 3      POLYGON ((83237.8372 2731224.84048778,83637.83...
# 4      POLYGON ((777437.8372 2712324.84048778,777437....
# ...                                                  ...
# 21675  POLYGON ((776237.8372 1996724.84048778,776237....
# 21676  POLYGON ((700537.8372 1927924.84048778,700537....
# 21677  POLYGON ((686637.8372 1921324.84048778,686637....
# 21678  POLYGON ((566137.8372 1899424.84048778,566137....
# 21679  POLYGON ((566037.8372 1899624.84048778,566037....
#
# [21680 rows x 1 columns]

# %%
df['Coordinates'] = geopandas.GeoSeries.from_wkt(df['Coordinates'])
df
# Out:
#                                              Coordinates
# 0      POLYGON ((59337.837 2722924.840, 59337.837 272...
# 1      POLYGON ((1051937.837 2725024.840, 1051537.837...
# 2      POLYGON ((351037.837 2718624.840, 351037.837 2...
# 3      POLYGON ((83237.837 2731224.840, 83637.837 273...
# 4      POLYGON ((777437.837 2712324.840, 777437.837 2...
# ...                                                  ...
# 21675  POLYGON ((776237.837 1996724.840, 776237.837 1...
# 21676  POLYGON ((700537.837 1927924.840, 700537.837 1...
# 21677  POLYGON ((686637.837 1921324.840, 686637.837 1...
# 21678  POLYGON ((566137.837 1899424.840, 566137.837 1...
# 21679  POLYGON ((566037.837 1899624.840, 566037.837 1...
#
# [21680 rows x 1 columns]

# %%
gdf = geopandas.GeoDataFrame(df, geometry='Coordinates')

print(gdf.head())
# Out:
#                                          Coordinates
# 0  POLYGON ((59337.837 2722924.840, 59337.837 272...
# 1  POLYGON ((1051937.837 2725024.840, 1051537.837...
# 2  POLYGON ((351037.837 2718624.840, 351037.837 2...
# 3  POLYGON ((83237.837 2731224.840, 83637.837 273...
# 4  POLYGON ((777437.837 2712324.840, 777437.837 2...

# %%
gdf.iloc[2]
# Out:
# Coordinates    POLYGON ((351037.837 2718624.840, 351037.837 2...
# Name: 2, dtype: geometry

# %%
gdf["area"] = gdf.area
gdf["area"]
gdf.plot(marker='*', color='green', markersize=1)
# Out:
# <img src="data:image/png;base64,..." width="732.6666666666666">
# <AxesSubplot:>

# %%
map_df = geopandas.read_file("./india-polygon.shp") 
map_df_copy = geopandas.read_file("./india-polygon.shp")
map_df.head()
# Out:
#      id                        st_nm  \
# 0  None  Andaman and Nicobar Islands
# 1  None            Arunachal Pradesh
# 2  None                        Assam
# 3  None                        Bihar
# 4  None                   Chandigarh
#
#                                             geometry
# 0  MULTIPOLYGON (((93.84831 7.24028, 93.92705 7.0...
# 1  POLYGON ((95.23643 26.68105, 95.19594 27.03612...
# 2  POLYGON ((95.19594 27.03612, 95.08795 26.94578...
# 3  POLYGON ((88.11357 26.54028, 88.28006 26.37640...
# 4  POLYGON ((76.84208 30.76124, 76.83758 30.72552...

# %%
map_df.plot()
# Out:
# <img src="data:image/png;base64,..." width="432">
# <AxesSubplot:>

# %%
base = map_df.plot(color='white', edgecolor='black')
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
gdf.plot(ax=base, marker='o', color='red', markersize=5);

# %%
fig, ax = plt.subplots()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
ax.set_aspect('equal')

# %%
map_df.plot(ax=ax, color='white', edgecolor='black')
# Out:
# <AxesSubplot:>

# %%
gdf.plot(ax=ax, marker='o', color='red', markersize=5)
# Out:
# <AxesSubplot:>

# %%
plt.show()
